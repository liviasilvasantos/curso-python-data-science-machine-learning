# %%
import numpy as np
import pandas as pd

# %%
data = {'Empresa': ['GOOG', 'GOOG', 'MSFT','MSFT', 'FB', 'FB'],
       'Nome':['Sam', 'Charlie', 'Amy', 'Vanessa', 'Carl', 'Sarah'],
       'Venda': [200,120,340,124,234,350]}

# %%
df = pd.DataFrame(data)

# %%
type(df)
df
# Out:
#   Empresa     Nome  Venda
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    234
# 5      FB    Sarah    350

# %%
dfg = df.groupby('Empresa')

# %%
dfg

# %%
dfg.sum()
# Out:
#          Venda
# Empresa
# FB         584
# GOOG       320
# MSFT       464

# %%
dfg.mean()
# Out:
#          Venda
# Empresa
# FB         292
# GOOG       160
# MSFT       232

# %%
dfg.describe()
# Out:
#         Venda
#         count   mean         std    min    25%    50%    75%    max
# Empresa
# FB        2.0  292.0   82.024387  234.0  263.0  292.0  321.0  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.0  160.0  180.0  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.0  232.0  286.0  340.0

# %%
dfg.count()
# Out:
#          Nome  Venda
# Empresa
# FB          2      2
# GOOG        2      2
# MSFT        2      2

# %%
df
# Out:
#   Empresa     Nome  Venda
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    234
# 5      FB    Sarah    350

# %%
dfg = df.groupby('Nome')

# %%
dfg.describe()
# Out:
#         Venda
#         count   mean std    min    25%    50%    75%    max
# Nome
# Amy       1.0  340.0 NaN  340.0  340.0  340.0  340.0  340.0
# Carl      1.0  234.0 NaN  234.0  234.0  234.0  234.0  234.0
# Charlie   1.0  120.0 NaN  120.0  120.0  120.0  120.0  120.0
# Sam       1.0  200.0 NaN  200.0  200.0  200.0  200.0  200.0
# Sarah     1.0  350.0 NaN  350.0  350.0  350.0  350.0  350.0
# Vanessa   1.0  124.0 NaN  124.0  124.0  124.0  124.0  124.0
